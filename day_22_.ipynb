# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavdhanisetti/AIML_NEOSKILLZ/blob/main/day_22_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("/content/Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
X=df[['area','bedrooms','bathrooms','stories','parking']]
Y=df['price']

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X, Y, test_size=0.2)

# %%
model=LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(X_test)

# %%
pred[:20]
# Out:
# array([6335721.95563267, 5892530.03498453, 3303077.30057003,
#        3717002.29342388, 3177949.90567131, 4883762.3906825 ,
#        3523727.32792249, 6082280.01043826, 7576881.40508263,
#        6739927.61136891, 4531584.28938709, 5852707.85101765,
#        7658591.42353088, 6430011.91884691, 6951903.62729274,
#        6314516.65033056, 4489768.97077263, 6309887.16369972,
#        5387418.06255571, 3079988.46958239])

# %%
print("MSE: ", mean_squared_error(Y_test, pred))
print("R2 :", r2_score(Y_test, pred))
# Out:
# MSE:  1530145038206.8716
# R2 : 0.6292969710951599
