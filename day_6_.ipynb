# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavdhanisetti/AIML_ZENOTALENT/blob/main/day_6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Installing MySQL Server and MySQL Workbench and setting up a local database connection
#MySQL Installer and MySQL Workbench was downloaded and full installation option was selected
#MySQL Installer must be downloaded first then Workbench
#After installation a new connection was created in MySQL Workbench using localhost port 3306 and root user
#A common error faced was inability to connect to MySQL Server mainly due to server not running
#MySQL Server service was checked using services.msc or MySQL Installer
#Server was configured again with development computer option strong password and Windows service enabled
#After configuration connection was tested again using the same local instance.
