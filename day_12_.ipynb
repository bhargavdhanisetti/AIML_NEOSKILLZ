# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavdhanisetti/AIML_NEOSKILLZ/blob/main/day_12_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SELECT id,name,marks,
#ROW_NUMBER() OVER (ORDER BY marks DESC) AS row_num
#FROM students;

#SELECT id,name,marks,
#RANK() OVER (ORDER BY marks DESC) AS row_order
#from students;

#SELECT id,name,marks,
#DENSE_RANK() OVER (ORDER BY marks DESC) AS row_order
#from students;

#SELECT name, city, marks,
#ROW_NUMBER () OVER (PARTITION BY city ORDER BY marksDESC) AS rank_city
#from students;

#SELECT id,name,marks,
#SUM(marks) OVER (ORDER BY marks DESC) AS totalp
#from students;

#SELECT name,city,marks,
#AVG(marks) OVER (PARTITION BY city) AS avg_city
#from students;

#SELECT name, city, marks,
#FIRST_VALUE (name) OVER (PARTITION BY city ORDER BY marks DESC) AS top_scorer
#from students;

#SELECT name,marks,
#PERCENT_RANK() OVER (ORDER BY marks DESC)AS persentile_ranks
#from students;
