# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavdhanisetti/AIML_ZENOTALENT/blob/main/day_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("sample.txt","w") as f:
  f.write("this is aiml and gen ai")
print("write succesfully")
# Out:
# write succesfully

# %%
with open("sample.txt","r") as f:
  c=f.read()
print(c)
# Out:
# this is aiml and gen ai

# %%
with open("sample.txt","a") as f:
  f.write(". tomorrow is holiday")

# %%
with open("sample.txt","r") as f:
  c=f.read()
print(c)
# Out:
# this is aiml and gen ai. tomorrow is holiday

# %%
with open("sample.txt","a") as f:
  f.write("\n hello world")

# %%
with open("sample.txt","r") as f:
  for line in f:
    print(line.strip())
# Out:
# this is aiml and gen ai. tomorrow is holiday
# hello world

# %%
a = [1,2,3]
b = a.copy()
print(b)
# Out:
# [1, 2, 3]

# %%
b=list(a)
print(b)
# Out:
# [1, 2, 3]
