# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavdhanisetti/AIML_NEOSKILLZ/blob/main/day_11_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#●FUNCTIONS

#SET time_zone =’+05:30’;
#SELECT CURRENT_DATE();
#SELECT NOW();
#SELECT DATE(NOW());
#SELECT TIME(NOW());

#SELECT
#NOW() AS today,
#YEAR(NOW()) AS year,
#MONTH(NOW()) AS month,
#DAY(NOW()) AS day;

#SELECT DATE_ADD(CURRENT_DATE(), INTERVAL 10 DAY);

#SELECT DATE_SUB(CURRENT_DATE(), INTERVAL 1 MONTH);

#SELECT DATEDIFF(‘2026-01-01’,CURRENT_DATE())
#AS days_left;

#CASE ELSE END
#SELECT name, marks,
#CASE
#WHEN marks>-90 THEN 'A+'
#WHEN marks>=75 THEN 'A'
#WHEN marks>=60 THEN 'B'
#WHEN marks>-35 THEN 'C'
#ELSE 'Fail'
#END AS Grade
