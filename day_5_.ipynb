# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavdhanisetti/AIML_ZENOTALENT/blob/main/day_5_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SQL for Data Analysis
#Master SQL fundamentals used in data Analysis with practical examples, joins, filtering, and aggregation

#1.Relational database basics
 #       A Relational database stores data in tables consisting of rows and columns
  #      Each table represents an entity, and relationships exist between these entities
   #     Rows are called as instance
    #    Columns are called as attributes

#Key concepts
#Table - structure of rows and columns
#Primary key - uniquely identify each record
#Foreign key- links one table to another

#2.SELECT Statements

#Used to fetch data from a database table.
#Example: SELECT Name, City FROM Customers:

#3.Filtering Data with WHERE

#The WHERE clause filters records based on a given condition.
#Example: SELECT FROM Orders WHERE Amount > 500:

#4.Sorting and LIMIT

#ORDER BY sorts data in ascending or descending order. LIMIT restricts the number of records returned.

#5.JOINS: Combining Data

#JOINS combine rows from two or more tables based on related columns.

#INNER JOIN - Returns records with matching values in both tables.

#LEFT JOIN - Returns all records from the left table and matched records from th right.

#RIGHT JOIN-Returns all from right table and matched from left.

#FULL JOIN - Returns all records when there is a match in one table.

#6.Aggregations: GROUP BY & HAVING

#Used for summarizing data like totals, averages, and counts.

#Example: SELECT CustomerID, SUM(Amount) AS Total_Spent FROM Orders GROUP BY CustomerID;

#7.Subqueries
#A subquery is a query inside another query
