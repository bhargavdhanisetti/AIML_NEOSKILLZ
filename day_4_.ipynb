# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavdhanisetti/AIML_ZENOTALENT/blob/main/day_4_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  a=15/0
except ZeroDivisionError:
  print("Cannot divide a number by zero")
# Out:
# Cannot divide a number by zero

# %%
try:
  a= int(input("Enter a number: "))
  result = 10/a
  print(result)
except ZeroDivisionError:
  print("Cannot divide a number by zero")
except ValueError:
  print("Entered non numeric value")
# Out:
# Enter a number: 0
# Cannot divide a number by zero

# %%
try:
  num = int("bhargav")
except ValueError:
  print("invalid value provided")
# Out:
# invalid value provided

# %%
try:
  file = open("text.txt","r")
  content = file.read()
  print(content)
except FileNotFoundError:
  print("File not found")
# Out:
# File not found

# %%
 student = {"name": "bhargav", "age":26}
 try:
  print(student["marks"])
except KeyError:
  print("key not present in dictionary")
# Out:
# key not present in dictionary

# %%
 num = [1,2,3]
 try:
  print(num[3])
except IndexError:
  print("index doesnt exist")
# Out:
# index doesnt exist

# %%
try:
  a = "100" - 6
except TypeError:
  print("you cannot subtract int from a string")
# Out:
# you cannot subtract int from a string

# %%
try:
  print(z)
except NameError:
  print("variable not found")
# Out:
# variable not found
